# %%
# !pip install twint 
# !pip3 install --user --upgrade git+https://github.com/twintproject/twint.git@origin/master#egg=twint
# Out:
# ...
#   Running command git clone -q https://github.com/twintproject/twint.git 'C:\Users\Giova\AppData\Local\Temp\pip-install-n82i5h9s\twint'
#   WARNING: Did not find branch or tag 'origin/master', assuming revision or ref.
#   Running command git checkout -q origin/master
#   WARNING: The script twint.exe is installed in 'C:\Users\Giova\AppData\Roaming\Python\Python38\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   Cloning https://github.com/twintproject/twint.git (to revision origin/master) to c:\users\giova\appdata\local\temp\pip-install-n82i5h9s\twint
# ...
#   Created wheel for twint: filename=twint-2.1.21-py3-none-any.whl size=39138 sha256=9b09f017262afe87b9ed2361a3c0704ef47e592fda164b846f02e44efea2a1a6
#   Stored in directory: C:\Users\Giova\AppData\Local\Temp\pip-ephem-wheel-cache-yzo2v3m0\wheels\82\67\14\5495652787d3c55288164de4234c0712a1f785a64f61f1ea70
# Successfully built twint
# ...

# %%
# !pip install nest-asyncio

# %%
import twint
from os import mkdir, path
import pandas as pd
import numpy as np 
import nest_asyncio
from glob import glob


pd.set_option("display.max_columns", 50)

# %%
from datetime import date, datetime, timedelta
from string import ascii_letters, digits
nest_asyncio.apply()

# %%
def clean_name(dirname):
    valid = set(ascii_letters + digits)
    return ''.join(a for a in dirname if a in valid)

# %%
def twint_search(hashtag, since, until, json_name):
    c = twint.Config()
    c.Search = hashtag
    c.Store_json = True
    c.Output = json_name
    c.Since = since
    c.Until = until
    try:
        twint.run.Search(c)    
    except (KeyboardInterrupt, SystemExit):
        raise
    except:
        print("Problem with %s." % since)

# %%
def twint_loop(searchterm, since, until):

    dirname = clean_name(searchterm)
    try:
    # Create target Directory
        mkdir(dirname)
        print("Directory" , dirname ,  "Created ")
    except FileExistsError:
        print("Directory" , dirname ,  "already exists")

    daterange = pd.date_range(since, until)

    for start_date in daterange:

        since = start_date.strftime("%Y-%m-%d")
        until = (start_date + timedelta(days=1)).strftime("%Y-%m-%d")

        json_name = '%s.json' % since
        json_name = path.join(dirname, json_name)

        print('Getting %s ' % since )
        twint_search(searchterm, since, until, json_name)

# %%
twint_loop('meloni', '2022-11-01', '2022-12-31')
# Out:
# Directory meloni Created
# Getting 2022-11-01
# 1587595189249576962 2022-11-02 00:59:23 +0100 <Fabrizi89066475> @Nero_Tulip @BBlunoir Purtroppo il popolo di milioni e milioni di evasori che vota Meloni e Salvini ha una marea di contanti in tasca. Il loro problema non è tanto pagare le bollette, quanto riuscire a pagarle in contanti. E su questo la Meloni li sta facendo felici.
# 1587595028138000387 2022-11-02 00:58:45 +0100 <VeritaLibertas> @RoxanaKreimer Es un clásico! La verdad existe un patrón en esta Derecha "Surrealista" ¿Que tienen en común Trump, Milei, Kast, Bolsonaro, Meloni, Abascal.... otros?, me parece que entienden que esta comunicación va a dar réditos electorales independiente de lo políticamente correcto que sean!
# 1587594875364687876 2022-11-02 00:58:09 +0100 <Ettore79597694> @ZanAlessandro Speriamo diano un taglio con i gaypride allora! Meloni la mia pdr!
# ...

# %%
file_names = glob(path.join('meloni','*.json'))
dfs = [pd.read_json(fn, lines = True) for fn in file_names]

dftrial = pd.concat(dfs)

dftrial_ita = dftrial[dftrial["language"] == "it"]

# %%
dftrial_ita.to_csv("meloni.csv")

# %%
twint_loop('calenda', '2022-11-01', '2022-12-31')

file_names = glob(path.join('calenda','*.json'))
dfs = [pd.read_json(fn, lines = True) for fn in file_names]

dftrial = pd.concat(dfs)

dftrial_ita = dftrial[dftrial["language"] == "it"]

dftrial_ita.to_csv("calenda.csv")
# Out:
# Directory calenda Created
# Getting 2022-11-01
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-11-02
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-11-03
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-11-04
# 1588681864738267137 2022-11-05 00:57:27 +0100 <lupovittorio42> @DavideRoss4 Per voi tutti quelli che sono contro Renzi e Calenda sono grillini..
# 1588680804657664001 2022-11-05 00:53:14 +0100 <lupovittorio42> @GiulianoNovell4 @CarloCalenda @matteorenzi Renzi e Calenda non sono di sinistra... Punto...
# 1588680732360441858 2022-11-05 00:52:57 +0100 <luigimariano66> @borghi_claudio Calenda è il più grosso pallone gonfiato della storia dei palloni gonfiati.
# 1588680583034863617 2022-11-05 00:52:21 +0100 <FerlitaCarlo> @CarloCalenda Certo che no… su Calenda non si può contare
# ...

# %%
twint_loop('partitodemocratico', '2022-11-01', '2022-12-31')

file_names = glob(path.join('partitodemocratico','*.json'))
dfs = [pd.read_json(fn, lines = True) for fn in file_names]

dftrial = pd.concat(dfs)

dftrial_ita = dftrial[dftrial["language"] == "it"]

dftrial_ita.to_csv("partitodemocratico.csv")
# Out:
# Directory partitodemocratico Created
# Getting 2022-11-01
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-11-02
# 1587954446918909953 2022-11-03 00:46:57 +0100 <sodom64276141> @lauraboldrini In quale paese democratico mette un partito democratico l’obbligo vaccinale e il partito di destra dello stesso paese democratico lo annulla? Stronza!
# 1587948286547197954 2022-11-03 00:22:28 +0100 <FrankoR_Ca> @CarloCarin1 @Tommasocerno Non è che hanno paura. Hanno preso a modello il partito democratico americano. Che di sinistra non ha proprio niente. Visto che porta avanti gli interessi della lobby delle armi. C’è molta confusione e soprattutto molta ignoranza. E qualche capo bastone che si è venduto.
# 1587943616093233154 2022-11-03 00:03:55 +0100 <ZanettiGilyNala> @SalazarYulia @kitty_b88 Questo è il partito DEMOCRATICO  https://t.co/QLZ3YVP1Jq
# ...

# %%
twint_loop('renzi', '2022-11-01', '2022-12-31')

file_names = glob(path.join('renzi','*.json'))
dfs = [pd.read_json(fn, lines = True) for fn in file_names]

dftrial = pd.concat(dfs)

dftrial_ita = dftrial[dftrial["language"] == "it"]

dftrial_ita.to_csv("renzi.csv")
# Out:
# Directory renzi Created
# Getting 2022-11-01
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-11-02
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-11-03
# 1588320008413007872 2022-11-04 00:59:34 +0100 <CecereBiancama1> @MicheleBonates3 Io mi vergogno che da buon bugiardo sia ancora in politica egli stesso  annunciò il suo ritiro, ma a tutt'oggi Renzi è lì!!!
# 1588319374720761856 2022-11-04 00:57:03 +0100 <MatteoBonicelli> @boni_castellane Perché lo suggerisce Renzi 😁
# 1588318264043917315 2022-11-04 00:52:38 +0100 <senzasinistra> @eu_pizzimenti @marioricciard18 #DeBenedetti #StefanoFeltri #Renzi un tris che se ti capita in mano quello che ti gioca contro di sicuro fa come minimo colore!!  E’ la famosa linea “#spostarsi a destra per #battere la destra”in voga nel Pd da 15anni .E’cosi che siam giunti al gov di Destra più nera,che tinge!
# ...

# %%
twint_loop('salvini', '2022-11-01', '2022-12-31')

file_names = glob(path.join('salvini','*.json'))
dfs = [pd.read_json(fn, lines = True) for fn in file_names]

dftrial = pd.concat(dfs)

dftrial_ita = dftrial[dftrial["language"] == "it"]

dftrial_ita.to_csv("salvini.csv")
# Out:
# Directory salvini Created
# Getting 2022-11-01
# 1587595189249576962 2022-11-02 00:59:23 +0100 <Fabrizi89066475> @Nero_Tulip @BBlunoir Purtroppo il popolo di milioni e milioni di evasori che vota Meloni e Salvini ha una marea di contanti in tasca. Il loro problema non è tanto pagare le bollette, quanto riuscire a pagarle in contanti. E su questo la Meloni li sta facendo felici.
# 1587593615412453378 2022-11-02 00:53:08 +0100 <AnnaStramigioli> #dimartedi @GiorgiaMeloni e @salvini, sinora, non sembrano antitetici, nell'equilibrio del governo, non per ora. Anzi potrebbero essere complementari e sinergici. L'elettorato premia entrambi nei sondaggi attuali.
# ...

# %%
twint_loop('terzopolo', '2022-11-01', '2022-12-31')

file_names = glob(path.join('terzopolo','*.json'))
dfs = [pd.read_json(fn, lines = True) for fn in file_names]

dftrial = pd.concat(dfs)

dftrial_ita = dftrial[dftrial["language"] == "it"]

dftrial_ita.to_csv("terzopolo.csv")
# Out:
# Directory terzopolo Created
# Getting 2022-11-01
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-11-02
# 1587922109212270595 2022-11-02 22:38:27 +0100 <CiccioC_02> @FraLauricella @CarloCalenda Ma che discorso è!!!! Vi rendete conto che la storia su Bin Salman non c'entra una beata minchia con le posizioni politiche di Renzi e del TerzoPolo, che dell'Arabia non parla e mai parlerà!  Consulenza PRIVATA SENZA OBBLIGHI POLITICI  Mi spiace ma è un argomento morto e sepolto
# 1587919655208833025 2022-11-02 22:28:42 +0100 <Sil__Cri> Dedicato a chi spera! “#Chidisperanzavive….  #ItaliaSulSerio  #2novembre2022 #TerzoPolo  https://t.co/jSIJCBoXEj
# 1587917281669140480 2022-11-02 22:19:16 +0100 <elizabethmaci> @ilfoglio_it @claudiocerasa E chi la voterebbe? Io (terzopolo) sicuramente no! Nemmeno se me lo chiedesse Renzi in persona. Voglio una figura nuova, competente e degna di rispetto.
# ...

# %%
twint_loop('fratelliditalia', '2022-11-01', '2022-12-31')

file_names = glob(path.join('fratelliditalia','*.json'))
dfs = [pd.read_json(fn, lines = True) for fn in file_names]

dftrial = pd.concat(dfs)

dftrial_ita = dftrial[dftrial["language"] == "it"]

dftrial_ita.to_csv("fratelliditalia.csv")
# Out:
# Directory fratelliditalia Created
# Getting 2022-11-01
# 1587594722146664448 2022-11-02 00:57:32 +0100 <supersonic_00> @FratellidItalia @DelmastroAndrea Comunque ha ragione. Direi che è più camicia nera, adesso.
# 1587594273599389696 2022-11-02 00:55:45 +0100 <Michele11480422> @FratellidItalia @GiorgiaMeloni Un vero saccheggio dei voti della lega ...
# 1587594021349822464 2022-11-02 00:54:45 +0100 <Eccalla> @1casopatologico @FratellidItalia @GiorgiaMeloni Il signor Meloni ha messo tutte persone di alto profilo e questa è una delle molte dimostrazioni.
# 1587593926084624384 2022-11-02 00:54:22 +0100 <TimpanaroLella1> @marcellogemmato @FratellidItalia Sobrio Fico ?… mah
# 1587593590989012997 2022-11-02 00:53:02 +0100 <FabrizioBenass4> @FratellidItalia  https://t.co/wCqgARYX0I
# 1587593554653609985 2022-11-02 00:52:54 +0100 <Emiliofracchia1> @SalvatoreTuozzi @FratellidItalia @GiorgiaMeloni Ma magari. Magari.
# ...

# %%
twint_loop('azione', '2022-11-01', '2022-12-31')

file_names = glob(path.join('azione','*.json'))
dfs = [pd.read_json(fn, lines = True) for fn in file_names]

dftrial = pd.concat(dfs)

dftrial_ita = dftrial[dftrial["language"] == "it"]

dftrial_ita.to_csv("azione.csv")
# Out:
# Directory azione Created
# Getting 2022-11-01
# 1587594444030853125 2022-11-02 00:56:26 +0100 <NulliusNihil> @Simona77124421 @dibellagf I provocatori di bolsonaro in azione,non è una novità.Gli USA cercano un altro colpo di Stato come in Cile .
# 1587594336283279360 2022-11-02 00:56:00 +0100 <Geggio7000> @mara_carfagna @Azione_it Sei una banderuola!!
# 1587594132398145538 2022-11-02 00:55:11 +0100 <NulliusNihil> @liliaragnar I provocatori di bolsonaro in azione,non è una novità.Gli USA cercano un altro colpo di Stato come in Cile .
# 1587593877044740101 2022-11-02 00:54:11 +0100 <ivana24041973> @gasparripdl sufficienza, in particolare nel tempo, che agisce con un meccanismo di azione completamente nuovo
# 1587593630902018048 2022-11-02 00:53:12 +0100 <LucioMM1> @marcoz984 non è la prima fattispecie di reato che prevede partecipazione in gruppo all'azione criminosa, nella + generica associazione a delinquere hai spesso pene comminate in quantità diversa per i vari partecipanti
# ...

# %%
twint_loop('letta', '2022-11-01', '2022-12-31')

file_names = glob(path.join('letta','*.json'))
dfs = [pd.read_json(fn, lines = True) for fn in file_names]

dftrial = pd.concat(dfs)

dftrial_ita = dftrial[dftrial["language"] == "it"]

dftrial_ita.to_csv("letta.csv")
# Out:
# Directory letta Created
# Getting 2022-11-01
# 1587595128113401861 2022-11-02 00:59:09 +0100 <trd_big> @EnricoLetta Ma l’hai letta la norma? Sai cosa vuole occupare abusivamente un luogo privato? State mostrando a tutti la vostra incapacità p, oltre che l’analfabetismo funzionale
# 1587595110639878146 2022-11-02 00:59:05 +0100 <LibertaNicola> @Stefania_67 Dopo 2 anni, come godo nel vedere il piddi dentro una fogna. SPERIAMO SIGNORISSIMO LETTA CHE SUBITO DOPO CI SIA UNA NUOVA NORIMBERGA PER TUTTI I DIRITTI UMANI NEGATI E LE CURE NEGATE E 200MILA MORTI CHE VOI NAZICOMUNISTI AVETE FATTO.
# 1587595084966821889 2022-11-02 00:58:59 +0100 <manera_mirella> @serracchiani Senti chi parla, il partito che ha fatto arrestare i manifestanti contro il green pass, che ha avvallato gli idranti contro i manifestanti di Trieste ecc ecc. Fate bene a difendere i disperati, forse sono gli unici che ancora vi votano. I deviati che piacciono a Letta.
# ...

# %%
twint_loop('conte', '2022-11-01', '2022-12-31')

file_names = glob(path.join('conte','*.json'))
dfs = [pd.read_json(fn, lines = True) for fn in file_names]

dftrial = pd.concat(dfs)

dftrial_ita = dftrial[dftrial["language"] == "it"]

dftrial_ita.to_csv("conte.csv")
# Out:
# Directory conte Created
# Getting 2022-11-01
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Getting 2022-11-02
# 1587957662561566720 2022-11-03 00:59:44 +0100 <_LiliMart> Jajajajjajaja yo cuando le conté que ya conocía toda su vida antes de conocernos jajajaja
# 1587957579476615168 2022-11-03 00:59:24 +0100 <joro781> @TottenhamTiers Either of the Italian teams. Conte would know how to beat them.
# 1587957547109343232 2022-11-03 00:59:16 +0100 <dyenniffers> @KarinFreitasss Me conte kkk
# 1587957489643003906 2022-11-03 00:59:03 +0100 <crybabycitla_> @reginaarys__ el q te conté
# 1587957402581745664 2022-11-03 00:58:42 +0100 <MoscaNaOrelha> Conte sua idade respondendo: Por qual você começou? Napster Kazaa eMule... Ou Spotify? rsrs  https://t.co/teN7lo9rUG
# 1587957398337110017 2022-11-03 00:58:41 +0100 <Bradesco> @C_Hernandez0 Olá, boa noite! O que aconteceu? Me conte mais detalhes por DM, por favor.  https://t.co/AZr1IzXD1m
# ...
